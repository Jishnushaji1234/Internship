# %%
#lets import all required librabries
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %%
#lets first connect to web driver
driver=webdriver.Chrome(r'C:/Users/jishn/Downloads/chromedriver_win32/chromedriver.exe')   
driver=webdriver.Chrome('chromedriver.exe')
url='https://www.naukri.com/'
driver.get(url)
search_job=driver.find_element_by_class_name("suggestor-input ")
search_job
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="503623ffb4bb0f96bca04a331331a62b", element="d13e5632-e191-4331-8f10-19be88f9cb5e")>

# %%
#write on search bar
search_job.send_keys("Data Scientist")
#finding web elemnt for search locn bar using absolute path
search_locn=driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[3]/div/div/div/input')
search_locn
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="503623ffb4bb0f96bca04a331331a62b", element="794173e9-230f-480d-9f30-a53fd53f5930")>

# %%
#finding web element for job location bar
search_locn.send_keys("Bangalore")
#clicking using absolute xpath function
search_btn=driver.find_element_by_xpath('/html/body/div/div[2]/div[3]/div/div/div[6]')
search_btn.click()

# %%
#lets extract all web elements having job titles
title_tags=driver.find_elements_by_xpath('//a[@class="title fw500 ellipsis"]')
job_titles=[]

for i in title_tags:
    job_titles.append(i.text)

    
company_tags=driver.find_elements_by_xpath('//a[@class="subTitle ellipsis fleft"]')
company_names=[]

for i in company_tags:
    company_names.append(i.text)
company_names[0:10]

exp_tags=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi experience"]')
experience=[]

for i in exp_tags:
    experience.append(i.text)
    
experience[0:10]
locn_tags=driver.find_elements_by_xpath('//li[@class="fleft grey-text br2 placeHolderLi location"]')
location=[]

for i in locn_tags:
    location.append(i.text)
    
location[0:10]
len(job_titles),len(company_names),len(experience),len(location)
# Out:
# (20, 20, 20, 20)

# %%
jobs=pd.DataFrame()
jobs['Job Title']=job_titles
jobs['Company']=company_names
jobs['Experience']=experience
jobs['Location']=location
jobs
# Out:
#                                             Job Title  \
# 0               Senior Data Scientist (R Programming)
# 1                                   Sr Data Scientist
# 2       Data Scientist/Senior Data Scientist - Python
# 3              HCL Tech Opening - Lead Data Scientist
# 4                                 Sr . Data Scientist
# 5                                  Data Scientist III
# 6   Need Data scientists and data engineers - WFH-...
# 7                            Principal Data Scientist
# 8                                      Data Scientist
# 9                                      Data Scientist
# 10                                     Data Scientist
# 11  Data Scientist - Machine Learning/Artificial I...
# 12                  Data Scientist - Machine Learning
# 13                     Senior Data Scientist Payments
# 14                         Sr. Product Data Scientist
# 15              Computer Vision Python Data Scientist
# 16                                     Data Scientist
# 17                                     Data Scientist
# 18                                Lead Data Scientist
# 19                           Data Scientist / Analyst
#
#                                    Company Experience  \
# 0                                  Ignitho    4-9 Yrs
# 1                                     Uber   6-12 Yrs
# 2                     ApicalGo Consultancy    3-8 Yrs
# 3                                      HCL  10-20 Yrs
# 4                                     Visa    6-8 Yrs
# 5                                  Groupon   6-11 Yrs
# 6   Covalense Technologies Private Limited   8-13 Yrs
# 7                    Mobile Premier League   8-12 Yrs
# 8                                    Shell    4-9 Yrs
# 9                                HDFC Bank    1-6 Yrs
# 10                              Connexions   5-10 Yrs
# 11                              Connexions    5-7 Yrs
# 12                  Corner Tree Consulting   6-10 Yrs
# 13                                 AirSeva   5-10 Yrs
# 14                                    Uber    2-7 Yrs
# 15                              OceanOfWeb    4-6 Yrs
# 16                                   Gojek   4-10 Yrs
# 17                        Minions Ventures    3-4 Yrs
# 18                                 Kyndryl    5-8 Yrs
# 19                        open data fabric    4-9 Yrs
#
#                                              Location
# 0                                              Remote
# 1                                 Bangalore/Bengaluru
# 2                                 Bangalore/Bengaluru
# 3   Kolkata, Hyderabad/Secunderabad, Pune, Chennai...
# 4                                 Bangalore/Bengaluru
# 5                                 Bangalore/Bengaluru
# 6   Hyderabad/Secunderabad, Bangalore/Bengaluru, M...
# 7                                 Bangalore/Bengaluru
# 8                                 Bangalore/Bengaluru
# 9   Pune, Gurgaon/Gurugram, Chennai, Bangalore/Ben...
# 10                                Bangalore/Bengaluru
# 11                                Bangalore/Bengaluru
# 12  Kolkata, Mumbai, Hyderabad/Secunderabad, Pune,...
# 13                                Bangalore/Bengaluru
# 14                                Bangalore/Bengaluru
# 15  Mumbai, Hyderabad/Secunderabad, Pune, Chennai,...
# 16                                Bangalore/Bengaluru
# 17                                Bangalore/Bengaluru
# 18                                Bangalore/Bengaluru
# 19                                Bangalore/Bengaluru
