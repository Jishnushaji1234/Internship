# %%
from bs4 import BeautifulSoup
import requests
page= requests.get('https://meesho.com/bags-ladies/pl/p7vbp')
soup=BeautifulSoup(page.content)
titles =[]
for i in soup.find_all('p',class_="Text__StyledText-sc-oo0kvp-0 bWSOET NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS NewProductCard__ProductTitle_Desktop-sc-j0e7tu-4 cQhePS"):
    titles.append(i.text)
    
    
titles
# Out:
# ['Elegant Attractive Women Handbags',
#  'Voguish Alluring Women Handbags',
#  'Voguish Fashionable Women Handbags',
#  'Gorgeous Classy Women Handbags',
#  'Classic Attractive Women Handbags',
#  'Elegant Stylish Women Handbags',
#  'Classic Alluring Women Handbags',
#  "Elegant Fancy Women'S Pu Leather Hand Bags",
#  "Elegant Fancy Women's Bags",
#  'Classic Fashionable Women Handbags',
#  'Wonderful Women Women Handbags',
#  'Elite Fancy Women Handbags',
#  'Trendy Stylish Women Handbags',
#  'Ravishing Stylish Women Handbags',
#  'Voguish Alluring Women Handbags',
#  'Trendy Fashionable Women Handbag ',
#  'Trendy Stylish Women Handbags',
#  'Elegant Versatile Women Handbags',
#  'Gorgeous Attractive Women Handbags',
#  'Elegant Classy Women Handbags']

# %%
Price=[]   
for i in soup.find_all('h5',class_="Text__StyledText-sc-oo0kvp-0 hiHdyy"):
    Price.append(i.text)

# %%
Price
# Out:
# ['₹510',
#  '₹203',
#  '₹227',
#  '₹187',
#  '₹130',
#  '₹210',
#  '₹189',
#  '₹164',
#  '₹181',
#  '₹267',
#  '₹206',
#  '₹137',
#  '₹201',
#  '₹151',
#  '₹469',
#  '₹189',
#  '₹189',
#  '₹199',
#  '₹187',
#  '₹296']

# %%
Discount=[]   
for i in soup.find_all('span',class_="Text__StyledText-sc-oo0kvp-0 lnonyH"):
    Discount.append(i.text)
    
    
Discount
# Out:
# ['16% off',
#  '34% off',
#  '38% off',
#  '33% off',
#  '51% off',
#  '30% off',
#  '30% off',
#  '37% off',
#  '34% off',
#  '34% off',
#  '35% off',
#  '33% off',
#  '37% off',
#  '52% off',
#  '25% off',
#  '35% off',
#  '30% off',
#  '30% off',
#  '35% off',
#  '30% off']

# %%
#making a data frame
import pandas as pd
df= pd.DataFrame({'PRODUCT NAME':titles,'PRICE':Price,'DISCOUNT':Discount})
df
# Out:
#                                   PRODUCT NAME PRICE DISCOUNT
# 0            Elegant Attractive Women Handbags  ₹510  16% off
# 1              Voguish Alluring Women Handbags  ₹203  34% off
# 2           Voguish Fashionable Women Handbags  ₹227  38% off
# 3               Gorgeous Classy Women Handbags  ₹187  33% off
# 4            Classic Attractive Women Handbags  ₹130  51% off
# 5               Elegant Stylish Women Handbags  ₹210  30% off
# 6              Classic Alluring Women Handbags  ₹189  30% off
# 7   Elegant Fancy Women'S Pu Leather Hand Bags  ₹164  37% off
# 8                   Elegant Fancy Women's Bags  ₹181  34% off
# 9           Classic Fashionable Women Handbags  ₹267  34% off
# 10              Wonderful Women Women Handbags  ₹206  35% off
# 11                  Elite Fancy Women Handbags  ₹137  33% off
# 12               Trendy Stylish Women Handbags  ₹201  37% off
# 13            Ravishing Stylish Women Handbags  ₹151  52% off
# 14             Voguish Alluring Women Handbags  ₹469  25% off
# 15           Trendy Fashionable Women Handbag   ₹189  35% off
# 16               Trendy Stylish Women Handbags  ₹189  30% off
# 17            Elegant Versatile Women Handbags  ₹199  30% off
# 18          Gorgeous Attractive Women Handbags  ₹187  35% off
# 19               Elegant Classy Women Handbags  ₹296  30% off
